# %%
import pandas as pd
df = pd.read_csv("covid_19_data.csv")

# %%
print(df.head())
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
print("Mean: ", df['Confirmed'].mean())
print("Standard Deviation: ", df['Confirmed'].std())
# Out:
# Mean:  585.3327674023769
# Standard Deviation:  4922.107404700659

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set()
plt.title("Confimed Cases Histogram")
df['Confirmed'].hist(bins = 50)

# %%
print("Mean: ", df['Recovered'].mean())
print("Standard Deviation: ", df['Recovered'].std())
# Out:
# Mean:  217.18590831918505
# Standard Deviation:  2417.208199826669

# %%
plt.title("Recovered Cases Histogram")
sns.set()
df['Recovered'].hist(bins = 50)

# %%
print("Mean: ", df['Deaths'].mean())
print("Standard Deviation: ", df['Deaths'].std())
# Out:
# Mean:  18.62597623089983
# Standard Deviation:  197.1613731651587

# %%
plt.title("Deaths Histogram")
sns.set()
df['Deaths'].hist(bins = 50)

# %%
from collections import Counter
print(Counter(df['Province/State'].values))
# Out:
# Counter({nan: 2315, 'Gansu': 56, 'Hebei': 56, 'Anhui': 54, 'Beijing': 54, 'Chongqing': 54, 'Fujian': 54, 'Guangdong': 54, 'Guangxi': 54, 'Guizhou': 54, 'Hainan': 54, 'Heilongjiang': 54, 'Henan': 54, 'Hong Kong': 54, 'Hubei': 54, 'Hunan': 54, 'Inner Mongolia': 54, 'Jiangsu': 54, 'Jiangxi': 54, 'Jilin': 54, 'Liaoning': 54, 'Macau': 54, 'Ningxia': 54, 'Qinghai': 54, 'Shaanxi': 54, 'Shandong': 54, 'Shanghai': 54, 'Shanxi': 54, 'Sichuan': 54, 'Tianjin': 54, 'Xinjiang': 54, 'Yunnan': 54, 'Zhejiang': 54, 'Taiwan': 49, 'New South Wales': 49, 'Victoria': 49, 'Tibet': 48, 'British Columbia': 48, 'Diamond Princess cruise ship': 48, 'Queensland': 46, 'South Australia': 44, 'Los Angeles, CA': 38, 'San Benito, CA': 36, 'Santa Clara, CA': 35, 'Tempe, AZ': 35, 'Boston, MA': 34, 'Toronto, ON': 34, 'London, ON': 34, 'Madison, WI': 34, 'Orange, CA': 32, 'Chicago, IL': 30, 'Seattle, WA': 30, 'San Diego County, CA': 28, 'San Antonio, TX': 26, 'From Diamond Princess': 23, 'Humboldt County, CA': 18, 'Sacramento County, CA': 18, 'Omaha, NE (From Diamond Princess)': 17, 'Travis, CA (From Diamond Princess)': 17, 'Lackland, TX (From Diamond Princess)': 17, 'Washington': 16, 'Ontario': 16, 'Western Australia': 16, 'Unassigned Location (From Diamond Princess)': 15, 'Tasmania': 14, 'Illinois': 13, 'California': 12, 'Arizona': 12, 'Northern Territory': 12, ' Montreal, QC': 10, 'Snohomish County, WA': 10, 'King County, WA': 8, 'Cook County, IL': 8, 'Grafton County, NH': 8, 'Hillsborough, FL': 8, 'Placer County, CA': 8, 'San Mateo, CA': 8, 'Sarasota, FL': 8, 'Sonoma County, CA': 8, 'Umatilla, OR': 8, 'Fulton County, GA': 7, 'Washington County, OR': 7, 'Maricopa County, AZ': 7, 'Wake County, NC': 7, 'Westchester County, NY': 7, 'Alberta': 7, 'Quebec': 7, 'Grand Princess': 7, 'Providence, RI': 6, 'Orange County, CA': 6, 'Contra Costa County, CA': 6, 'New York': 6, 'Massachusetts': 6, 'Georgia': 6, 'Colorado': 6, 'Florida': 6, 'New Jersey': 6, 'Oregon': 6, 'Texas': 6, 'Pennsylvania': 6, 'Iowa': 6, 'Maryland': 6, 'North Carolina': 6, 'South Carolina': 6, 'Tennessee': 6, 'Virginia': 6, 'Indiana': 6, 'Kentucky': 6, 'District of Columbia': 6, 'Nevada': 6, 'New Hampshire': 6, 'Minnesota': 6, 'Nebraska': 6, 'Ohio': 6, 'Rhode Island': 6, 'Wisconsin': 6, 'Connecticut': 6, 'Hawaii': 6, 'Oklahoma': 6, 'Utah': 6, 'Kansas': 6, 'Louisiana': 6, 'Missouri': 6, 'Vermont': 6, 'Arkansas': 6, 'Delaware': 6, 'Idaho': 6, 'Maine': 6, 'Michigan': 6, 'Mississippi': 6, 'Montana': 6, 'New Mexico': 6, 'North Dakota': 6, 'South Dakota': 6, 'West Virginia': 6, 'Wyoming': 6, ' Norfolk County, MA': 5, 'Bergen County, NJ': 5, 'Harris County, TX': 5, 'San Francisco County, CA': 5, 'Clark County, NV': 5, 'Fort Bend County, TX': 5, 'Grant County, WA': 5, 'Santa Rosa County, FL': 5, 'Williamson County, TN': 5, 'Alaska': 5, 'France': 5, 'Denmark': 5, 'Faroe Islands': 5, 'St Martin': 5, 'Channel Islands': 5, 'New Brunswick': 5, 'Saint Barthelemy': 5, 'Gibraltar': 5, 'Bavaria': 4, 'New York City, NY': 4, 'Berkeley, CA': 4, 'New York County, NY': 4, 'Unassigned Location, WA': 4, 'Montgomery County, MD': 4, 'Suffolk County, MA': 4, 'Denver County, CO': 4, 'Summit County, CO': 4, 'Chatham County, NC': 4, 'Delaware County, PA': 4, 'Douglas County, NE': 4, 'Fayette County, KY': 4, 'Marion County, IN': 4, 'Middlesex County, MA': 4, 'Nassau County, NY': 4, 'Ramsey County, MN': 4, 'Washoe County, NV': 4, 'Wayne County, PA': 4, 'Yolo County, CA': 4, 'None': 3, 'Portland, OR': 3, 'Calgary, Alberta': 3, 'Santa Clara County, CA': 3, 'Grand Princess Cruise Ship': 3, 'Douglas County, CO': 3, 'Providence County, RI': 3, 'Alameda County, CA': 3, 'Broward County, FL': 3, 'Fairfield County, CT': 3, 'Lee County, FL': 3, 'Pinal County, AZ': 3, 'Rockland County, NY': 3, 'Saratoga County, NY': 3, 'Charleston County, SC': 3, 'Clark County, WA': 3, 'Cobb County, GA': 3, 'Davis County, UT': 3, 'El Paso County, CO': 3, 'Honolulu County, HI': 3, 'Jackson County, OR ': 3, 'Jefferson County, WA': 3, 'Kershaw County, SC': 3, 'Kla ...

# %%
df.dropna(inplace=True)
print(Counter(df['Province/State'].values).most_common(5))
# Out:
# [('Gansu', 56), ('Hebei', 56), ('Anhui', 54), ('Beijing', 54), ('Chongqing', 54)]

# %%
df = df[df['Province/State'].isin(['Anhui', 'Beijing', 'Chongqing'])]
sns.boxplot(x= df['Province/State'], y = df['Confirmed'])
plt.show()

# %%
df = df[df['Province/State'].isin(['Anhui', 'Beijing', 'Chongqing'])]
sns.boxplot(x= df['Province/State'], y = df['Recovered'])
plt.show()

# %%
df = df[df['Province/State'].isin(['Anhui', 'Beijing', 'Chongqing'])]
sns.boxplot(x= df['Province/State'], y = df['Deaths'])
plt.show()

# %%
import pillow
print(pillow.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-12ca7cb5bf08> in <module>
# ----> 1 import pillow
#       2 print(pillow.__version__)
#
# ModuleNotFoundError: No module named 'pillow'
